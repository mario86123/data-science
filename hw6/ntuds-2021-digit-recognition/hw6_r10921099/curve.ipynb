# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
loss = pd.read_csv('./sample_codes/loss.csv', sep=',')
loss
# Out:
#     Unnamed: 0  train_loss  test_loss
# 0            0    0.291650   0.144259
# 1            1    0.119274   0.118427
# 2            2    0.090631   0.106228
# 3            3    0.077385   0.091774
# 4            4    0.072753   0.091874
# 5            5    0.065513   0.082516
# 6            6    0.060626   0.078381
# 7            7    0.056739   0.079480
# 8            8    0.053816   0.080845
# 9            9    0.051548   0.073794
# 10          10    0.048218   0.073702
# 11          11    0.045930   0.079884
# 12          12    0.045075   0.072686
# 13          13    0.043736   0.076053
# 14          14    0.040384   0.075210
# 15          15    0.040616   0.073382
# 16          16    0.038641   0.068751
# 17          17    0.037518   0.066781
# 18          18    0.036470   0.068109
# 19          19    0.036475   0.069277
# 20          20    0.033207   0.082946
# 21          21    0.034241   0.062928
# 22          22    0.036533   0.064948
# 23          23    0.032015   0.069891
# ...

# %%
plt.plot(list(range(len(loss['train_loss']))), loss['train_loss'], label='train_loss')
plt.plot(list(range(len(loss['test_loss']))), loss['test_loss'], label='test_loss')
plt.legend()
plt.show()
