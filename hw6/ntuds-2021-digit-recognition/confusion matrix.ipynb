# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
predict = pd.read_csv('./sample_codes/experiment/train/output.csv', sep=',')
predict['label'].to_numpy()
# Out:
# array([4, 7, 1, ..., 5, 7, 6])

# %%
truth = pd.read_csv('./digit/valid.csv', sep=',')
truth['label'].to_numpy()
# Out:
# array([4, 7, 9, ..., 5, 3, 6])

# %%
cm = confusion_matrix(predict['label'].to_numpy(), truth['label'].to_numpy())
cm
# Out:
# array([[1391,    6,   21,    7,   10,   12,   25,    2,   19,   21],
#        [  21, 1679,   22,    9,   41,   13,   24,   19,   44,   17],
#        [  12,   17, 1281,   25,    7,   36,   20,   10,   19,    9],
#        [   3,    3,   30, 1421,    6,   91,    2,    6,   48,   10],
#        [   2,    4,    4,    0, 1345,    3,    2,    6,    8,   12],
#        [   2,    1,    2,    4,    0, 1136,   16,    0,   15,    4],
#        [  18,    4,   13,    3,    8,   12, 1369,    1,   24,    3],
#        [   9,   17,   40,   44,   28,   29,    1, 1533,   24,   81],
#        [   3,    0,    6,    6,    2,   15,    2,    0, 1112,    6],
#        [  14,    1,    3,   11,   74,   13,    7,   17,   70, 1352]])

# %%
plt.figure(figsize = (10, 10))
sns.set(font_scale=1.5)
sns.heatmap(cm, annot=True, cmap="Greens")
plt.show()
